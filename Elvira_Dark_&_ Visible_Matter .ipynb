# %%
#Elvira Cruz-Cruz

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exploring SPARC Galaxy Sample

# %% [markdown]
# #### Plotting the Surface brightness of each galaxy at different radii.

# %%
galaxy_name = 'NGC4138'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'UGC06614'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC0891'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC1090'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC2976'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC3917'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC4010'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'UGC00128'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'UGC00191'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'UGC00731'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'DDO168'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC2915'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'UGC03546'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
galaxy_name = 'NGC7814'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()

# %%
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """

# %% [markdown]
# ### Density Distribution of Visible and Dark Matter

# %%
GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))

# %%
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   if __name__ == '__main__':

# %% [markdown]
# ##### In NGC7814’s density plot, the density of visible matter is seen to be higher than the total density in the central region of the galaxy. This may be due to the mass to light ratio being less than 1 in the central region of the galaxy compared to the visible mass observed at different regions.

# %% [markdown]
# ### Appling the Mass-to-Light Ratio to NGC7814

# %%
ML_ratio= 1.461
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in sqrt
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Applying $\chi^2$ per degree of freedom to NGC7814

# %%
chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# Chi squared per degree of freedom =  77.02983704520398

# %% [markdown]
# ### Exploring galaxies in SPARC Galaxy Sample

# %%
galaxy_name = 'UGC03546'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 1.09999
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in sqrt
# Chi squared per degree of freedom =  59.27849915462599

# %%
galaxy_name = 'NGC3917'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 1.5613
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in sqrt
# Chi squared per degree of freedom =  4.997855408581765

# %% [markdown]
# ### SPARC Galaxy Sample Models in which dark matter is not needed to fit visible matter to the observed rotational speeds.
# ##### Only using Mass-to-Light ratios
# ##### ($\chi^2$ < 1)

# %%
galaxy_name = 'D512-2'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 2.21
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# Chi squared per degree of freedom =  0.9507651650058855

# %%
galaxy_name = 'F561-1'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 0.9
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in sqrt
# Chi squared per degree of freedom =  0.6352477401718724

# %%
galaxy_name = 'F563-V1'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 1.0
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in sqrt
# Chi squared per degree of freedom =  0.17410504733432194

# %%
galaxy_name = 'F563-V2'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 6.1
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# Chi squared per degree of freedom =  0.49263563458701864

# %%
galaxy_name = 'F567-2'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 1.9
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# Chi squared per degree of freedom =  0.29975905493872046

# %%
galaxy_name = 'F574-2'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 0.6
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in sqrt
# Chi squared per degree of freedom =  0.10001591843163175

# %% [markdown]
# #### Below is an interesting galaxy (for me)

# %%
galaxy_name = 'F568-1'

R, V_obs, error_V_obs, V_gas, V_disk, V_bulge, SB_disk, SB_bulge = np.loadtxt('SPARC_data/'+galaxy_name+'_rotmod.dat', unpack=True)

fig=plt.figure(figsize=(7,5))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R,SB_disk,'o', color='red', label='Disk')

if sum(SB_bulge)>0.:
    ax.plot(R,SB_bulge,'o', color='Turquoise', label='Bulge')
    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Surface brightness [solar luminosity/parsec$^2$]')
ax.legend()
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible = np.sqrt(V_gas**2 + V_disk**2 + V_bulge**2)
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='Turquoise', linewidth=1.2, label='Disk')
if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge')

ax.plot(R, V_visible, '-', color='Blue', label='Total visible matter')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

GNewton=4.43e-6   # kpc (km/s)2 / solar mass
V_shell=[(4./3)*np.pi*R[0]**3]
M_shell=[R[0]*V_obs[0]**2/GNewton]
M_vis_shell=[ R[0]*V_visible[0]**2/GNewton ]
R_midpt = [0.5*R[0]]
for i in range(1,len(R)):
    V_shell.append( (4./3)*np.pi*(R[i]**3 - R[i-1]**3) )
    M_shell.append( R[i]*V_obs[i]**2/GNewton - M_shell[i-1])
    M_vis_shell.append(R[i]*V_visible[i]**2/GNewton - M_vis_shell[i-1] )
    R_midpt.append(0.5*(R[i]+R[i-1]))
    
density = np.array(M_shell)/np.array(V_shell)
vis_density = np.array(M_vis_shell)/np.array(V_shell)
fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(R_midpt,density,'-', label='Total mass density')
ax.plot(R_midpt, vis_density, '-', label='Visible matter' )
ax.plot(R_midpt, density-vis_density, label='Dark matter')
ax.set_ylim([0,1.2*np.max(density)])
ax.set_xlabel('radius [kpc]')
ax.set_ylabel('density [M$_{sun}$/kpc$^3$]')
ax.set_title(galaxy_name)
ax.legend()

ML_ratio= 5.7
M_stars= V_disk**2 * R/GNewton
V_stars_adjusted = np.sqrt(GNewton* np.array(M_stars) /R)
V_stars_adjusted = np.sqrt(ML_ratio)*V_disk
V_bulge_adjusted = np.sqrt(ML_ratio)*V_bulge

fig=plt.figure(figsize=(7,6))
ax=fig.add_subplot(111)

V_visible_adjusted = np.sqrt(V_gas**2 + V_stars_adjusted**2 + V_bulge_adjusted**2 )
V_DM = np.sqrt(V_obs**2 - V_visible**2)

ax.errorbar(R, V_obs , yerr=error_V_obs, marker='o', color='Salmon', label='Observed')
ax.plot(R, V_gas, '--', color='green', linewidth=1.2, label='Gas')
ax.plot(R, V_disk, '--', color='turquoise', linewidth=1.2, label='Disk (M/L=1)')
ax.plot(R, V_stars_adjusted, '-', color='turquoise', linewidth=1.2, label='Disk (M/L='+repr(ML_ratio)+')')

if sum(V_bulge)>0.:
    ax.plot(R, V_bulge, '--', color='purple', linewidth=1.2, label='Bulge (M/L=1)')
    ax.plot(R, V_bulge, '-', color='purple', linewidth=1.2, label='Bulge (M/L='+repr(ML_ratio)+')')

ax.plot(R, V_visible_adjusted, '-', color='blue', label='Total visible matter (M/L='+repr(ML_ratio)+')')
ax.plot(R, V_DM, '-', color='black', label='Inferred dark matter')


    
ax.set_title(galaxy_name)
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('V_{rot} ~[km/s]')
ax.set_ylim([0,1.8*np.max(V_obs)])

ax.legend(fontsize=13)

chi2=0.
for i in range(len(R)):
    chi2+=(V_obs[i]-V_visible_adjusted[i])**2/error_V_obs[i]**2
deg_of_freedom=len(R)-1
chi2_per_dof=chi2/deg_of_freedom
print('Chi squared per degree of freedom = ',chi2_per_dof)
# Out:
# /anaconda2/envs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:60: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# Chi squared per degree of freedom =  1.5658999327687477

# %% [markdown]
# ##### In the galaxy(F568-1) above dark matter density dominates visible matter density at about 1.1 kpc.
# ##### Type: Sc
