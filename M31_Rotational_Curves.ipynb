# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arcmin= 90

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=90 arcmin')

# %%
arcmin= 94.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=94.5 arcmin')

# %%
arcmin= 99

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=99 arcmin')

# %%
arcmin= 103.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=103.5 arcmin')

# %%
arcmin= 108

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=108 arcmin')

# %%
arcmin= 112.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=112.5 arcmin')

# %%
arcmin= 117

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=117 arcmin')

# %%
arcmin= 121.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=121.5 arcmin')

# %%
arcmin= 126

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=126 arcmin')

# %%
arcmin= 130.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=130.5 arcmin')

# %%
arcmin= 135

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=135 arcmin')

# %%
arcmin= 139.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=139.5 arcmin')

# %%
arcmin= 144

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=144 arcmin')

# %%
arcmin= 148.5

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=148.5 arcmin')

# %%
arcmin= 153

datafile='data/'+repr(arcmin)+'arcmin.dat'
freq, intensity = np.loadtxt(datafile, unpack=True)
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.plot(freq,intensity,'o')
ax.set_xlabel('Frequency (MHz)')
ax.set_ylabel('Intensity (Janskys)')
ax.set_title('Distance from center='+repr(arcmin)+' arcmin')
# Out:
# Text(0.5, 1.0, 'Distance from center=153 arcmin')

# %%
radii = [5.657,6.7895,7.9211,9.0528,10.184577,11.3163,12.4481,13.58004,14.71196,15.8439,16.97602,18.108151,19.2403,20.3726,21.3917,22.4109,23.43027,24.44963,25.46908,26.48861,27.508244,28.527964,29.54778,30.567703,31.587728,32.607861,33.628106,34.648466]
v_rot= [435.393566,442.9387988,451.3450806,462.3372386,459.319916,455.440355,451.9917083,452.4228275,451.1295722,445.5254317,432.5919567,431.7297182,435.6098939,427.3908702,419.8316874,417.5270584,420.3130987,422.3104438,421.2964071,420.5281974,417.0046759,416.8305484,414.8741745,415.5604418,425.1067269,426.8889732,428.8248615,421.7880612]
fig = plt.figure(figsize= (8,6))
ax= fig.add_subplot(111)

rdisk, Mdisk = np.loadtxt('Menclosed_stellar_disk.txt', unpack=True)
rbulge, Mbulge=np.loadtxt('Menclosed_stellar_bulge.txt',unpack=True)
rgas, Mgas =np.loadtxt('Menclosed_hydrogen_gas.txt', unpack=True)

G=4.32e-6 
ax.plot(radii, v_rot, 'o-', color='red', label='Rotational Velocity Curve')
ax.plot(rdisk, np.sqrt(G*Mdisk/rdisk), '--', label='Stellar disk')
ax.plot(rbulge, np.sqrt(G*Mbulge/rbulge), '--', label='Stellar bulge')
ax.plot(rgas, np.sqrt(G*Mgas/rgas), '--', label='Hydrogen gas')


ax.legend()

ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Rotational velocity [km/s]')
# Out:
# Text(0, 0.5, 'Rotational velocity [km/s]')

# %%
mass_enclosed=[2.48079E+11,3.08152E+11,3.73287E+11,4.47652E+11,4.97066E+11,5.4301E+11,5.88307E+11,6.43028E+11,6.92649E+11,7.27524E+11,7.34908E+11,7.80797E+11,8.44593E+11,8.60869E+11,8.7224E+11,9.03792E+11,9.57554E+11,1.00873E+12,1.04575E+12,1.08365E+12,1.10659E+12,1.14665E+12,1.17652E+12,1.22116E+12,1.32055E+12,1.37465E+12,1.43055E+12,1.42598E+12]

fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)

ax.plot(radii, mass_enclosed, 'o-', color='green')
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Mass enclosed within radius R [solar masses]')
# Out:
# Text(0, 0.5, 'Mass enclosed within radius R [solar masses]')

# %% [markdown]
# Total Visible Mass of M31 = 1.17594e+11 solar masses
#
# #Not accurate because velocities are off by ~20%
# #Total Mass (from Mass Enclosed vs Radius Plot) =1.42598e+12 solar masses
# #Ratio of Visible Mass to Total Mass = 0.0824653922
# #Mass of Dark Matter in M31 = 1.308386e+12 Solar Masses
# #Ratio of Dark Matter Mass to Visible Matter Mass = 11.12629896

# %%
radii_below_37kpc = [5.657,6.7895,7.9211,9.0528,10.184577,11.3163,12.4481,13.58004,14.71196,15.8439,16.97602,18.108151,19.2403,20.3726,21.3917,22.4109,23.43027,24.44963,25.46908,26.48861,27.508244,28.527964,29.54778,30.567703,31.587728,32.607861,33.628106,34.648466]
v_rot= [435.393566,442.9387988,451.3450806,462.3372386,459.319916,455.440355,451.9917083,452.4228275,451.1295722,445.5254317,432.5919567,431.7297182,435.6098939,427.3908702,419.8316874,417.5270584,420.3130987,422.3104438,421.2964071,420.5281974,417.0046759,416.8305484,414.8741745,415.5604418,425.1067269,426.8889732,428.8248615,421.7880612]
radii_above_37kpc = [5.657,6.7895,7.9211,9.0528,10.184577,11.3163,12.4481,13.58004,14.71196,15.8439,16.97602,18.108151,19.2403,20.3726,21.3917,22.4109,23.43027,24.44963,25.46908,26.48861,27.508244,28.527964,29.54778,30.567703,31.587728,32.607861,33.628106,34.648466,37,38,39,40,41,42,43,44,45,47,48,50,52,54,55,57,58,59,60,62,64,65,70,75,80,82,83,86]
v_visible = [17.92074781,21.50838205,25.09316519,28.67826512,32.26360897,35.84878176,39.43419848,43.0200587,46.60585556,50.19171579,53.77814623,57.36461152,60.95113383,64.53813449,67.76653012,70.99524254,74.2244935,77.45371279,80.68321718,83.912975,87.14306229,90.37342201,93.60408585,96.83508866,100.0664146,103.2980826,106.5301055,109.7624927,117.2118913,115.6593473,114.1669061,112.7307873,111.347535,110.0139835,108.727226,107.4845883,106.2836055,103.9976693,102.9086585,100.8294814,98.87144099,97.0232137,96.13713839,94.43546165,93.61782322,92.8210613,92.04430236,90.54754729,89.12151254,88.43330523,85.21646519,82.32692681,79.71270412,78.73459709,78.25885498,76.88175879]

fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
plt.xticks(np.arange(0, 90, 5.0))
plt.yticks(np.arange(0, 500, 50.0))
ax.plot(radii_below_37kpc, v_rot, '-o', color='red', label='Observed')
ax.plot(radii_above_37kpc, v_visible, '-x', color='blue', label='Prediction from visible matter')
ax.set_xlabel('Radius [kpc]')
ax.set_ylabel('Rotational velocity [km/s]')
ax.legend()

# %% [markdown]
# The predicted rotational velocity curve compared to the observed rotational velocity curve is linearly increasing until reaching a radius of ~37kpc and decreases/stablizes as the distance increases from the center of the galaxy. This is due to the assumption that M31 is made up of only visible matter and the mass is distributed in a sphere of uniform density. The observed rotational curve includes both dark matter and visible matter.
